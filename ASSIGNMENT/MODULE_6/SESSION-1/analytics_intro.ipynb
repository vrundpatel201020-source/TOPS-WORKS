# %%
name = "vrund"
Favorite_app = "you Tube"

print("name:", name)
print("Favorite App:", Favorite_app)
# Out:
# name: vrund
# Favorite App: you Tube

# %%
import datetime

print("Current Year:", datetime.datetime.now().year)
# Out:
# Current Year: 2026
